# %% [markdown]
# <a href="https://colab.research.google.com/github/attiqbhai/ai-courses/blob/main/data-analysis-with-pandas-and-python/chapter-4-dataFrames-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter-4 DataFrames - Part-1

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
pd.__version__
# Out:
# '2.2.2'
